# %% [markdown]
# <a href="https://colab.research.google.com/github/torrancefredell/gss_project/blob/main/GSS_Project_Tables.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Research Question:** How does the distribution of occupational prestige vary among different levels of marriage happiness and sexes in the married population?

# %%
import pandas as pd
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/My Drive/Spring 2024/DS 3001/cleaned_gss.csv', index_col=0)

# %%
df.head()
# Out:
#     age     sex  educ marital_status        work_status  \
# 1  36.0  female  11.0        married  working full time
# 2  32.0    male  12.0        married  working full time
# 3  55.0    male  12.0        married  working full time
# 4  43.0  female  16.0        married  working part time
# 5  27.0    male  16.0        married  working full time
#
#                                           occupation  \
# 1  inspectors, testers, sorters, samplers, and we...
# 2                     stock clerks and order fillers
# 3                                retail salespersons
# 4  sales representatives,  wholesale and manufact...
# 5                             postsecondary teachers
#
#    combined_respondent_prestige  respondent_hours_worked   income  \
# 1                          39.0                     40.0  12500.0
# 2                          25.0                     40.0  12500.0
# 3                          31.0                     60.0   5500.0
# ...

# %%
df.describe()
# Out:
#                 age          educ  combined_respondent_prestige  \
# count  14015.000000  14095.000000                  14122.000000
# mean      42.086621     13.884285                     45.688996
# std       11.431608      2.877375                     12.987408
# min       18.000000      0.000000                     16.000000
# 25%       33.000000     12.000000                     35.000000
# 50%       41.000000     14.000000                     45.000000
# 75%       51.000000     16.000000                     53.000000
# max       89.000000     20.000000                     80.000000
#
#        respondent_hours_worked        income  spouse_prestige  \
# count             14122.000000  13184.000000     14122.000000
# mean                 41.161025  22984.412925        45.344640
# std                  13.966894   4602.611045        12.995856
# min                   0.000000   1000.000000        16.000000
# 25%                  37.000000  25000.000000        35.000000
# ...

# %% [markdown]
# **Describing Variables of Interest**

# %%
df.groupby('marriage_happiness').describe()
# Out:
#                        age                                                \
#                      count       mean        std   min   25%   50%   75%
# marriage_happiness
# not too happy        387.0  42.108527  10.319939  21.0  34.0  42.0  49.0
# pretty happy        4789.0  42.179161  10.885121  18.0  34.0  41.0  50.0
# very happy          8839.0  42.035524  11.762957  18.0  33.0  41.0  51.0
#
#                             educ             ... spouse_prestige        \
#                      max   count       mean  ...             75%   max
# marriage_happiness                           ...
# not too happy       69.0   391.0  13.455243  ...            50.0  80.0
# pretty happy        89.0  4827.0  13.764864  ...            52.0  80.0
# very happy          89.0  8877.0  13.968120  ...            53.0  80.0
#
#                    spouse_hours_worked                                         \
#                                  count       mean        std  min   25%   50%
# ...

# %%
df.groupby('sex').describe()
# Out:
#            age                                                        educ  \
#          count       mean        std   min   25%   50%   75%   max   count
# sex
# female  7327.0  40.825986  11.115341  18.0  32.0  40.0  49.0  89.0  7370.0
# male    6687.0  43.468970  11.613525  19.0  34.0  43.0  52.0  89.0  6716.0
#
#                    ... spouse_prestige       spouse_hours_worked             \
#              mean  ...             75%   max               count       mean
# sex                ...
# female  13.876934  ...            53.0  80.0              7381.0  45.076819
# male    13.892198  ...            54.0  80.0              6727.0  36.688122
#
#
#               std  min   25%   50%   75%   max
# sex
# female  12.168028  0.0  40.0  40.0  50.0  89.0
# male    12.352079  0.0  30.0  40.0  40.0  89.0
#
# [2 rows x 56 columns]

# %%
df.groupby('combined_respondent_prestige').describe()
# Out:
#                                 age                                           \
#                               count       mean        std   min    25%   50%
# combined_respondent_prestige
# 16.0                           19.0  38.052632  11.097916  22.0  30.50  38.0
# 17.0                           61.0  40.721311  11.790012  22.0  31.00  41.0
# 18.0                           16.0  38.000000  11.413442  20.0  30.50  37.0
# 20.0                            4.0  42.500000  23.586719  25.0  26.50  34.5
# 21.0                           75.0  40.120000  11.749595  21.0  30.00  41.0
# 22.0                           53.0  39.207547  11.153403  20.0  32.00  37.0
# 23.0                            9.0  33.777778   9.024658  22.0  27.00  35.0
# 24.0                          241.0  43.875519  13.334208  19.0  33.00  43.0
# 25.0                          374.0  42.187166  12.323053  18.0  32.25  42.0
# 26.0                           49.0  43.081633  13.931135  23.0  33.00  41.0
# ...

# %%
# Descriptive Statistics
df.groupby(['marriage_happiness', 'sex']).describe()['combined_respondent_prestige']
# Out:
#                             count       mean        std   min   25%   50%  \
# marriage_happiness sex
# not too happy      female   252.0  43.115079  12.990598  16.0  32.0  45.0
#                    male     140.0  44.600000  13.201155  17.0  35.0  43.0
# pretty happy       female  2572.0  44.821151  12.940995  16.0  35.0  46.0
#                    male    2257.0  44.802836  12.687936  16.0  35.0  44.0
# very happy         female  4557.0  45.770682  12.845090  16.0  36.0  47.0
#                    male    4330.0  46.793303  13.204173  17.0  37.0  45.0
#
#                              75%   max
# marriage_happiness sex
# not too happy      female  50.00  80.0
#                    male    50.25  80.0
# pretty happy       female  53.00  80.0
#                    male    51.00  80.0
# very happy         female  54.00  80.0
#                    male    56.00  80.0
